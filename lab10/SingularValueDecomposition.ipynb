# %%
import numpy as np
import pandas as pd

# %%
def clean_text(text, stemm=True):
    # split into words
    from nltk.tokenize import word_tokenize
    tokens = word_tokenize(text)

    # convert to lower case
    tokens = [w.lower() for w in tokens]

    # remove punctuation from each word
    import string
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]

    # remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]

    # filter out stop words
    from nltk.corpus import stopwords
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]

    if not stemm:
        return sorted(words)
    
    # stemming of words
    from nltk.stem.porter import PorterStemmer
    porter = PorterStemmer()
    stemmed = [porter.stem(word) for word in words]
    
    return sorted(stemmed)

# %%
def generate_vocab(texts):
    words = set()
    for text in texts:
        words.update(text)         
    vocab = sorted(list(words))
    return vocab

# %%
def generate_bow(text, vocab):
    bag = np.zeros(len(vocab), dtype='int')
    words, c = np.unique(text, return_counts=True)
    for i, w in enumerate(words):
        for j, word in enumerate(vocab):
            if word == w: 
                bag[j] += c[i]
    return bag

# %%
def genereate_tbd(texts):
    vocab = generate_vocab(texts)
    A = np.zeros((len(vocab),0))

    for i, text in enumerate(texts):
        A = np.insert(A, i, np.transpose(generate_bow(text, vocab)), axis=1)
    
    return vocab, A

# %%
data = pd.read_csv('songdata.csv')
data.head()
# Out:
#   artist              song                                               text
# 0   ABBA         All I Ask  Look at her face, it's a wonderful face  \nAnd...
# 1   ABBA  Andante, Andante  Take it easy with me, please  \nTouch me gentl...
# 2   ABBA    As Good As New  I'll never know why I had to go  \nWhy I had t...
# 3   ABBA              Bang  Making somebody happy is a question of give an...
# 4   ABBA  Bang-A-Boomerang  Making somebody happy is a question of give an...

# %%
texts = data['text'].values[:1000]

# %%
cleaned_texts = np.array([clean_text(text, stemm=True) for text in texts])

# %%
vocab, A = genereate_tbd(cleaned_texts)

# %%
np.savetxt('vocab.txt', vocab, delimiter=',', fmt='%s')
np.savetxt('A.txt', A, delimiter=',', fmt='%d')

# %%
vocab = np.genfromtxt('vocab.txt',dtype='str').tolist()
A = np.genfromtxt('A.txt', delimiter=',', dtype='int')

# %%
def IDF(bag):
    N = bag.shape[1]
    nw = bag.shape[0] - np.count_nonzero(bag == 0, axis=1)
    idf = np.multiply(bag, np.reshape(np.log(N / nw), (len(vocab),1)))
    return np.abs(idf)

# %%
def normalize_matrix(A):
    normalized = A / np.apply_along_axis(np.linalg.norm, 0, A)
    return normalized

def normalize_vector(v):
    normalized = v / np.linalg.norm(v)
    return normalized

# %%
k = 5
search = "You are the Dancing Queen, young and sweet, only seventeen"

cleaned_search = clean_text(search, stemm=True)
print("cleaned text\n", cleaned_search)

q = np.reshape(generate_bow(cleaned_search, vocab), (1, len(vocab)))
# Out:
# cleaned text
#  ['danc', 'queen', 'seventeen', 'sweet', 'young']

# %%
idf_A = IDF(A)

# %%
corr = normalize_vector(q).dot(normalize_matrix(A))
idf_corr = normalize_vector(q).dot(normalize_matrix(idf_A))

# %%
display(data.iloc[np.flip(np.argsort(corr)[0][-k:])])

print("IDF")

display(data.iloc[np.flip(np.argsort(idf_corr)[0][-k:])])
# Out:
#               artist                song  \
# 74              ABBA      Reina Danzante
# 11              ABBA       Dancing Queen
# 527  Alice In Chains  Queen Of The Rodeo
# 888    Avril Lavigne                  17
# 53              ABBA     Love Isn't Easy
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 527  My daddy was a trucker  \nLeft home when I was...
# 888  He was working at the record shop  \nI would k...
# 53   Do you remember the first time, and all of you...
# IDF
#               artist                song  \
# 74              ABBA      Reina Danzante
# 11              ABBA       Dancing Queen
# 527  Alice In Chains  Queen Of The Rodeo
# 888    Avril Lavigne                  17
# 53              ABBA     Love Isn't Easy
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 527  My daddy was a trucker  \nLeft home when I was...
# 888  He was working at the record shop  \nI would k...
# 53   Do you remember the first time, and all of you...

# %%
def low_rank_approx(A=None, r=1):
    SVD = np.linalg.svd(A, full_matrices=False)
    u, s, v = SVD
    Ar = np.zeros((len(u), len(v)))
    for i in range(r):
        Ar += s[i] * np.outer(u.T[i], v[i])
    return Ar

# %%
for r in range(10, 101, 10):
    Ak = low_rank_approx(A, r)
    idf_Ak = IDF(Ak)

    kcorr = normalize_vector(q).dot(normalize_matrix(Ak))
    idf_kcorr = normalize_vector(q).dot(normalize_matrix(idf_Ak))

    print("r = {}".format(r))
    
    display(data.iloc[np.flip(np.argsort(kcorr)[0][-k:])])
    
    print("IDF")

    display(data.iloc[np.flip(np.argsort(idf_kcorr)[0][-k:])])
# Out:
# r = 10
#             artist                   song  \
# 124    Ace Of Base               Who Am I
# 890  Avril Lavigne  Anything But Ordinary
# 327     Air Supply                Someone
# 609     Alphaville          Forever Young
# 355  Aiza Seguerra              Open Arms
#
#                                                   text
# 124  I was born in the shadows  \nUnder the Iberian...
# 890  Sometimes I get so weird  \nI even freak mysel...
# 327  When you first found love  \nWas it all that y...
# 609  Let's start in style, let's dance for a while,...
# 355  Intro:  \n  \nLying beside you, here in the da...
# IDF
#             artist            song  \
# 513   Alice Cooper          Poison
# 753  Andy Williams   My Sweet Lord
# 818   Arlo Guthrie    Percy's Song
# 287     Air Supply      I Want You
# 899  Avril Lavigne  Fall To Pieces
#
#                                                   text
# 513  Your cruel device  \nYour blood, like ice  \nO...
# 753  My sweet Lord  \nHmm, my Lord  \nHmm, my Lord ...
# 818  Bad news, bad news, come to me where I sleep  ...
# 287  If it's love that you want, there will always ...
# 899  I looked away  \nThen I looked back at you  \n...
# r = 20
#              artist                         song  \
# 349   Aiza Seguerra               I See You Lord
# 753   Andy Williams                My Sweet Lord
# 736  Andrea Bocelli                        Sogno
# 411         Alabama  If I Could Just See You Now
# 355   Aiza Seguerra                    Open Arms
#
#                                                   text
# 349  I'm so blessed my Lord  \nI can see you  \nIn ...
# 753  My sweet Lord  \nHmm, my Lord  \nHmm, my Lord ...
# 736  SOGNO  \n  \nVa ti aspettero'  \nII fiore nel ...
# 411  Your love for me is gone  \nBut my love for yo...
# 355  Intro:  \n  \nLying beside you, here in the da...
# IDF
#              artist                         song  \
# 349   Aiza Seguerra               I See You Lord
# 753   Andy Williams                My Sweet Lord
# 736  Andrea Bocelli                        Sogno
# 411         Alabama  If I Could Just See You Now
# 355   Aiza Seguerra                    Open Arms
#
#                                                   text
# 349  I'm so blessed my Lord  \nI can see you  \nIn ...
# 753  My sweet Lord  \nHmm, my Lord  \nHmm, my Lord ...
# 736  SOGNO  \n  \nVa ti aspettero'  \nII fiore nel ...
# 411  Your love for me is gone  \nBut my love for yo...
# 355  Intro:  \n  \nLying beside you, here in the da...
# r = 30
#             artist               song  \
# 349  Aiza Seguerra     I See You Lord
# 753  Andy Williams      My Sweet Lord
# 74            ABBA     Reina Danzante
# 11            ABBA      Dancing Queen
# 732      Amy Grant  Sweet Will Of God
#
#                                                   text
# 349  I'm so blessed my Lord  \nI can see you  \nIn ...
# 753  My sweet Lord  \nHmm, my Lord  \nHmm, my Lord ...
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 732  My stubborn will at last hath yielded  \nI wou...
# IDF
#             artist               song  \
# 349  Aiza Seguerra     I See You Lord
# 753  Andy Williams      My Sweet Lord
# 74            ABBA     Reina Danzante
# 11            ABBA      Dancing Queen
# 732      Amy Grant  Sweet Will Of God
#
#                                                   text
# 349  I'm so blessed my Lord  \nI can see you  \nIn ...
# 753  My sweet Lord  \nHmm, my Lord  \nHmm, my Lord ...
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
#
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 96   They came from the hills  \nAnd they came from...
# 10   Oh, my love it makes me sad.  \nWhy did things...
# 256  Hot sun as warm as the kissing of the wind  \n...
# r = 90
#                    artist                                        song  \
# 74                   ABBA                              Reina Danzante
# 11                   ABBA                               Dancing Queen
# 96                   ABBA                                   The Piper
# 10                   ABBA                                       Dance
# 457  Alan Parsons Project  The Fall Of The House Of Usher - I Prelude
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 96   They came from the hills  \nAnd they came from...
# 10   Oh, my love it makes me sad.  \nWhy did things...
# 457  [instrumental]  \n  \n(I) Prelude  \n  \n"Shad...
# IDF
#                    artist                                        song  \
# 74                   ABBA                              Reina Danzante
# 11                   ABBA                               Dancing Queen
# 96                   ABBA                                   The Piper
# 10                   ABBA                                       Dance
# 457  Alan Parsons Project  The Fall Of The House Of Usher - I Prelude
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 96   They came from the hills  \nAnd they came from...
# 10   Oh, my love it makes me sad.  \nWhy did things...
# 457  [instrumental]  \n  \n(I) Prelude  \n  \n"Shad...
# r = 100
#                    artist                                        song  \
# 74                   ABBA                              Reina Danzante
# 11                   ABBA                               Dancing Queen
# 96                   ABBA                                   The Piper
# 10                   ABBA                                       Dance
# 457  Alan Parsons Project  The Fall Of The House Of Usher - I Prelude
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 96   They came from the hills  \nAnd they came from...
# 10   Oh, my love it makes me sad.  \nWhy did things...
# 457  [instrumental]  \n  \n(I) Prelude  \n  \n"Shad...
# IDF
#                    artist                                        song  \
# 74                   ABBA                              Reina Danzante
# 11                   ABBA                               Dancing Queen
# 96                   ABBA                                   The Piper
# 10                   ABBA                                       Dance
# 457  Alan Parsons Project  The Fall Of The House Of Usher - I Prelude
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 96   They came from the hills  \nAnd they came from...
# 10   Oh, my love it makes me sad.  \nWhy did things...
# 457  [instrumental]  \n  \n(I) Prelude  \n  \n"Shad...

# %%
def find(vocab, A, search, k=5, stemm=True, idf=False, svd=False, r=80):
    cleaned_search = clean_text(search, stemm=stemm)
    
    q = np.reshape(generate_bow(cleaned_search, vocab), (1, len(vocab)))
    
    if not svd:
        if not idf:
            corr = normalize_vector(q).dot(normalize_matrix(A))
            return np.flip(np.argsort(corr)[0][-k:])
        else:
            idf_A = IDF(A)
            idf_corr = normalize_vector(q).dot(normalize_matrix(idf_A))
            return np.flip(np.argsort(idf_corr)[0][-k:])
    else:
        Ak = low_rank_approx(A, r)
        if not idf:
            kcorr = normalize_vector(q).dot(normalize_matrix(Ak))
            return np.flip(np.argsort(kcorr)[0][-k:])
        else:
            idf_Ak = IDF(Ak)
            idf_kcorr = normalize_vector(q).dot(normalize_matrix(idf_Ak))
            return np.flip(np.argsort(idf_kcorr)[0][-k:])

# %%
search = "You are the Dancing Queen, young and sweet, only seventeen"
findings = find(vocab, A, search, 5)
print(findings)
display(data.iloc[findings])
# Out:
# [ 74  11 527 888  53]
#               artist                song  \
# 74              ABBA      Reina Danzante
# 11              ABBA       Dancing Queen
# 527  Alice In Chains  Queen Of The Rodeo
# 888    Avril Lavigne                  17
# 53              ABBA     Love Isn't Easy
#
#                                                   text
# 74   You can dance  \nYou can jive  \nHaving the ti...
# 11   You can dance, you can jive, having the time o...
# 527  My daddy was a trucker  \nLeft home when I was...
# 888  He was working at the record shop  \nI would k...
# 53   Do you remember the first time, and all of you...
